# %% [markdown]
# # EDA — Comisiones
#
# Explore the raw SP comisiones file.

# %%
import pandas as pd
from pathlib import Path

RAW = Path('../data/raw/comisiones')
files = list(RAW.glob('*.xls*'))
print(f'Files found: {len(files)}')

# %%
if files:
    df = pd.read_excel(files[0], header=0)
    print(df.shape)
    print(df.dtypes)
    df.head()
